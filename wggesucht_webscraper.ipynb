# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import os
from unidecode import unidecode

city = "Köln"
max_rent = 500
# specify the URL of the search results page for Cologne WG-Zimmer on wg-gesucht.de
#url = "https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Koeln.73.1.1.0.html?offer_filter=1&city_id=73&sort_order=0&noDeact=1&categories[]=1&rent_types[]=0&sMin=15&rMax=500"


# specify the URL of the search results page for Cologne WG-Zimmer on wg-gesucht.de
url = "https://www.wg-gesucht.de/wg-zimmer-in-Koeln.73.0.1.0.html"
# send a GET request to the URL and get the HTML content of the page
response = requests.get(url)

html_content = response.content

# parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# find all listings on the page
listings = soup.find_all(class_='wgg_card offer_list_item')

# define a regular expression pattern to match the relevant information in the string
pattern = r"(\d)er WG[\s|]*(\S+)[\s|]*(\S+)[\s|]*(\S+.*)"

# create an empty list to store the data
data = []

# loop through each listing and extract the information
for listing in listings:
    title = listing.find(class_='truncate_title noprint').text.strip()
    price = listing.find(class_='col-xs-3').text.strip()
    size = listing.find(class_='col-xs-3 text-right').text.strip()
    
    # parse single informations with regex
    merged_infos = listing.find(class_='col-xs-11').text.replace('\n', '')

    match = re.search(pattern, merged_infos, re.MULTILINE)
    if match is not None:
        # extract the relevant information from the match object
        wg_type = match.group(1)
        city = match.group(2).strip()
        district = match.group(3).strip()
        street = match.group(4).strip()
        
        # append the extracted data to the list
        data.append([title, price, size, wg_type, city, district, street])
    
    else: 
        print("No match found")

# create a pandas DataFrame from the extracted data
df = pd.DataFrame(data, columns=['Title', 'Price', 'Size', 'WG Type', 'City', 'District', 'Street'])

# save the DataFrame to a CSV file in the current working directory
file_path = os.path.join(os.getcwd(), 'wg_listings.csv')
df.to_csv(file_path, index=False)

# print a message to confirm that the file has been saved
print(f"DataFrame saved to {file_path}")
# Out:
# DataFrame saved to c:\Coding\wggesucht_webscraper\wg_listings.csv

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import os
import logging
from unidecode import unidecode

city = "Köln"
max_rent = 500
# specify the URL of the search results page for Cologne WG-Zimmer on wg-gesucht.de
url = "https://www.wg-gesucht.de/wg-zimmer-in-Koeln.73.1.1.0.html?offer_filter=1&city_id=73&sort_order=0&noDeact=1&categories[]=1&rent_types[]=0&sMin=15&rMax=500"


# specify the URL of the search results page for Cologne WG-Zimmer on wg-gesucht.de
#url = "https://www.wg-gesucht.de/wg-zimmer-in-Koeln.73.0.1.0.html"
# send a GET request to the URL and get the HTML content of the page
response = requests.get(url)

html_content = response.content

# parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# find all listings on the page
listings = soup.find_all(class_='wgg_card offer_list_item')

# define a regular expression pattern to match the relevant information in the string
pattern = r"(\d)er WG[\s|]*(\S+)[\s|]*(\S+)[\s|]*(\S+.*)"

# create an empty list to store the data
data = []

# set up logging
logging.basicConfig(filename='merged_info.log', level=logging.INFO, format='%(asctime)s:%(message)s')

# loop through each listing and extract the information
for listing in listings:
    title = listing.find(class_='truncate_title noprint').text.strip()
    price = listing.find(class_='col-xs-3').text.strip()
    size = listing.find(class_='col-xs-3 text-right').text.strip()
    
    # parse single informations with regex
    merged_infos = listing.find(class_='col-xs-11').text.replace('\n', '')
    
    # log the value of merged_infos
    logging.info(merged_infos)

    match = re.search(pattern, merged_infos, re.MULTILINE)
    if match is not None:
        # extract the relevant information from the match object
        wg_type = match.group(1)
        city = match.group(2).strip()
        district = match.group(3).strip()
        street = match.group(4).strip()
        
        # append the extracted data to the list
        data.append([title, price, size, wg_type, city, district, street])
    
    else: 
        print("No match found")

# create a pandas DataFrame from the extracted data
df = pd.DataFrame(data, columns=['Title', 'Price', 'Size', 'WG Type', 'City', 'District', 'Street'])

# save the DataFrame to a CSV file in the current working directory
file_path = os.path.join(os.getcwd(), 'wg_listings.csv')
df.to_csv(file_path, index=False)

# print a message to confirm that the file has been saved
print(f"DataFrame saved to {file_path}")
# Out:
# No match found
# No match found
# No match found
# No match found
# No match found
# No match found
# No match found
# No match found
# No match found
# No match found
# No match found
# No match found
# No match found
# No match found
# No match found
# No match found
# No match found
# No match found
# No match found
# No match found
# DataFrame saved to c:\Coding\wggesucht_webscraper\wg_listings.csv

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
from unidecode import unidecode

city = "Köln"
max_rent = 500
# specify the URL of the search results page for Cologne WG-Zimmer on wg-gesucht.de
url = "https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Koeln.73.1.1.0.html?offer_filter=1&city_id=73&sort_order=0&noDeact=1&categories[]=1&rent_types[]=0&sMin=15&rMax=500"
#url = f"https://www.wg-gesucht.de/wg-zimmer-in-{unidecode(city)}.73.0.1.0.html?offer_filter=1&city_id=73&sort_order=0&noDeact=1&categories[]=1&rent_types[]=0&sMin=15&rMax={max_rent}"#
# send a GET request to the URL and get the HTML content of the page
response = requests.get(url)

html_content = response.content

# parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# find all listings on the page
listings = soup.find_all(class_='wgg_card offer_list_item')


# define a regular expression pattern to match the relevant information in the string
pattern = r"(\d)er WG[\s|]*(\S+)[\s|]*(\S+)[\s|]*(\S+.*)"

# create an empty list to store the data
data = []

# loop through each listing and extract the information
for listing in listings:
    title = listing.find(class_='truncate_title noprint').text.strip()
    print(title)
    price = listing.find(class_='col-xs-3').text.strip()
    size = listing.find(class_='col-xs-3 text-right').text.strip()
    
    # parse single informations with regex
    merged_infos = listing.find(class_='col-xs-11').text.replace('\n', '')
    print(merged_infos)

    match = re.search(pattern, merged_infos, re.MULTILINE)
    if match is not None:
        # extract the relevant information from the match object
        wg_type = match.group(1)
        city = match.group(2).strip()
        district = match.group(3).strip()
        street = match.group(4).strip()
        
        # append the extracted data to the list
       
    
    else: 
        print("No match found")

    data.append([title, price, size, wg_type, city, district, street])

# create a pandas DataFrame from the extracted data
df = pd.DataFrame(data, columns=['Title', 'Price', 'Size', 'WG Type', 'City', 'District', 'Street'])

# print the DataFrame
print(df)
# Out:
# NUR TAUSCH!!! 1,5 Zimmer-Wohnung mit Balkon in Bickendorf
#                         1-Zimmer-Wohnung                          |                                                                                    Köln                                                        Bickendorf |                                                Erlenweg
# No match found
# Einzimmerwohnung 45 m² in Köln verfügbar April
#                         1-Zimmer-Wohnung                          |                                                                                    Köln                                                        Sülz |                                                Redwitzstr. 76
# No match found
# Billiger übernachtung
#                         1-Zimmer-Wohnung                          |                                                                                    Köln                                                        Mülheim |                                                Keup straße119
# No match found
# Helle 1-Zimmer-Wohnung - Köln Süd (07.04. - 14.04.)
#                         1-Zimmer-Wohnung                          |                                                                                    Köln                                                        Neustadt-Süd |                                                Meister-Gerhard-Str.
# No match found
# TAUSCHE 1Zimmer Wohnung in Sülz  gegen andere Wohnung
#                         1-Zimmer-Wohnung                          |                                                                                    Köln                                                        Sülz |                                                Wichterichstraße 4
# No match found
# Traum wohnung
#                         1-Zimmer-Wohnung                          |                                                                                    Köln                                                        Mülheim |                                                Keup straße119
# No match found
# *befristete Zwischenmiete*
# 1-Zimmer Wohnung im Belgischen Viertel
#                         1-Zimmer-Wohnung                          |                                                                                    Köln                                                        Belgisches Viertel |                                                Brüsseler Straße 4
# No match found
# TAUSCHANGEBOT 1-Zimmer WHG in der Innenstadt gegen 2-Zimmer WHG
#                         1-Zimmer-Wohnung                          |                                                                                    Köln                                                        Altstadt-Nord |                                                Greesbergstraße
# No match found
# Zimmer zur Untermiete in Köln-Lövenich
#                         1-Zimmer-Wohnung                          |                                                                                    Köln                                                        Lövenich |                                                Zaunstraße
# No match found
# Voll ausgestattete Wohnung zur FIBO
#                         1-Zimmer-Wohnung                          |                                                                                    Köln                                                        Lindenthal |                                                Mommsenstraße
# No match found
# Ferienwohnung mit Terrasse
#                         1-Zimmer-Wohnung                          |                                                                                    Köln                                                        Bocklemünd/Mengenich |                                                Untere Dorfstr.
# No match found
# Gemütliche 1-Zimmer Wohnung mitten im Belgischen
#                         1-Zimmer-Wohnung                          |                                                                                    Köln                                                
m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185'],
#  ['Einzimmerwohnung 45 m² in Köln verfügbar April',
#   '400 €',
#   '45 m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185'],
#  ['Billiger übernachtung',
#   '25 €',
#   '59 m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185'],
#  ['Helle 1-Zimmer-Wohnung - Köln Süd (07.04. - 14.04.)',
#   '125 €',
#   '31 m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185'],
#  ['TAUSCHE 1Zimmer Wohnung in Sülz  gegen andere Wohnung',
#   '490 €',
#   '27 m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185'],
#  ['Traum wohnung',
#   '25 €',
#   '59 m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185'],
#  ['*befristete Zwischenmiete*\n1-Zimmer Wohnung im Belgischen Viertel',
#   '260 €',
#   '39 m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185'],
#  ['TAUSCHANGEBOT 1-Zimmer WHG in der Innenstadt gegen 2-Zimmer WHG',
#   '400 €',
#   '23 m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185'],
#  ['Zimmer zur Untermiete in Köln-Lövenich',
#   '395 €',
#   '22 m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185'],
#  ['Voll ausgestattete Wohnung zur FIBO',
#   '500 €',
#   '37 m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185'],
#  ['Ferienwohnung mit Terrasse',
#   '60 €',
#   '40 m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185'],
#  ['Gemütliche 1-Zimmer Wohnung mitten im Belgischen',
#   '380 €',
#   '35 m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185'],
#  ['1-Zimmerwohnung am Rathenauplatz zur Zwischenmiete für paar Wochen',
#   '400 €',
#   '25 m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185'],
#  ['Helle 1-Zimmer Wohnung mit Balkon in Top Lage',
#   '60 €',
#   '26 m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185'],
#  ['Sofa-bed available in a cozy flat',
#   '30 €',
#   '20 m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185'],
#  ['Wunderschöne Einzimmerwohnung über Ostern 05.04.23-15.04.23',
#   '320 €',
#   '26 m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185'],
#  ['Babysitten gegen kostenfreies Wohnen - TOP LAGE nahe des Rheinauhafens ab 15.04.',
#   '1 €',
#   '15 m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185'],
#  ['Tausche Wohnung in Berlin gegen Wohnung in Köln',
#   '470 €',
#   '25 m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185'],
#  ['EinzelzimmerWohnung',
#   '315 €',
#   '17 m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185'],
#  ['Studio im inklusiven Haus  "Wohnen für Hilfe"',
#   '2 €',
#   '36 m²',
#   '3',
#   'Köln',
#   'Neuehrenfeld',
#   'Vogelsanger Str. 185']]

# %%
merged_infos
# Out:
# '                        1-Zimmer-Wohnung                          |                                                                                    Köln                                                        Rodenkirchen |                                                Sürther Feldallee 12                    '

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import os


# specify the URL of the search results page for Cologne WG-Zimmer on wg-gesucht.de
url = "https://www.wg-gesucht.de/wg-zimmer-in-Koeln.73.0.1.0.html"
# send a GET request to the URL and get the HTML content of the page
response = requests.get(url)

html_content = response.content

# parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# find all listings on the page
listings = soup.find_all(class_='wgg_card offer_list_item')

# define a regular expression pattern to match the relevant information in the string
pattern = r"(\d)er WG[\s|]*(\S+)[\s|]*(\S+)[\s|]*(\S+.*)"

# create an empty list to store the data
data = []

# loop through each listing and extract the information
for listing in listings:
    title = listing.find(class_='truncate_title noprint').text.strip()
    price = listing.find(class_='col-xs-3').text.strip()
    size = listing.find(class_='col-xs-3 text-right').text.strip()
    
    # parse single informations with regex
    merged_infos = listing.find(class_='col-xs-11').text.replace('\n', '')

    match = re.search(pattern, merged_infos, re.MULTILINE)
    if match is not None:
        # extract the relevant information from the match object
        wg_type = match.group(1)
        city = match.group(2).strip()
        district = match.group(3).strip()
        street = match.group(4).strip()
        
        # append the extracted data to the list
        data.append([title, price, size, wg_type, city, district, street])
    
    else: 
        print("No match found")

# create a pandas DataFrame from the extracted data
df = pd.DataFrame(data, columns=['Title', 'Price', 'Size', 'WG Type', 'City', 'District', 'Street'])

></span>
#  </div>
#  </div>
#  <div class="col-xs-11">
#  <span>
#                          7er WG
#                           |
#
#                                                                                      Köln
#
#                              Bornheim - Sechtem |
#
#                          Bahnhofstr. 3
#                      </span>
#  <span class="noprint" title="7er WG (2w,4m,0d)">
#  <img alt="weiblich" class="vis" height="17" src="/img/wgw.gif" style="margin-left:0px;" width="10"/><img alt="weiblich" class="vis" height="17" src="/img/wgw.gif" style="margin-left:-1px;" width="10"/><img alt="Malmännliche" class="vis" height="17" src="/img/wgm.gif" style="margin-left:0px;" width="10"/><img alt="Malmännliche" class="vis" height="17" src="/img/wgm.gif" style="margin-left:-1px;" width="10"/><img alt="Malmännliche" class="vis" height="17" src="/img/wgm.gif" style="margin-left:-1px;" width="10"/><img alt="Malmännliche" class="vis" height="17" src="/img/wgm.gif" style="margin-left:-1px;" width="10"/><img alt="Mitbewohnerin gesucht" class="vis" height="17" src="/img/wgwg.gif" style="margin-left:0px;" width="10"/> </span>
#  </div>
#  </div>
#  <div class="row noprint middle">
#  <div class="col-xs-3">
#  <b>499 €</b>
#  </div>
#  <div class="col-xs-5 text-center">
#                                                                      01.06.2023
#
#                                      </div>
#  <div class="col-xs-3 text-right">
#  <b>18 m²</b>
#  </div>
#  </div>
#  <div class="row noprint bottom">
#  <div class="col-xs-2">
#  <img class="avatar" src="/img/placeholder/no_profile_image_unisex.svg"/>
#  </div>
#  <div class="col-xs-9">
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <span>
#  </span>
#  <span>
#  </span>
#  </div>
#  </div>
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <span class="ml5">Mike</span>
#  <span style="color: #218700;">Online: 1 Stunde</span>
#  </div>
#  </div>
#  </div>
#  <div class="col-xs-1 text-center p0">
#  <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden"></span>
#  </div>
#  </div>
#  </div>
#  <div class="printonly">
#  <a class="detailansicht" href="/wg-zimmer-in-Koeln-Bornheim--Sechtem.9719592.html">
#  <b>Große Haus-WG Köln/Bonn</b>
#  </a>
#  <br/>
#  <div>
#  <b>499 € |</b>
#  <b>18 m²</b>
#  </div>
#  <div>
#                  7er WG
#                   |
#
#                                                              Köln
#
#                      Bornheim - Sechtem |
#
#                  Bahnhofstr. 3
#              </div>
#  <div style="margin-bottom:10px;">
#  <b>
#                      Verfügbar:
#                      01.06.2023
#                  </b>
#  </div>
#  <div style="margin-bottom:10px;">
#  <i>Diese Anzeige ist erreichbar unter:</i> https://www.wg-gesucht.de/9719592.html
#              </div>
#  <div style="border-top: 2px solid #ddd; margin-bottom:10px"></div>
#  </div>
#  </div>
#  </div>,
#  <div class="wgg_card offer_list_item" data-id="6654704" id="liste-details-ad-6654704">
#  <div class="row">
#  <div class="col-sm-4 card_image">
#  <a href="/wg-zimmer-in-Koeln-Ehrenfeld.6654704.html" style="background-image: url(https://www.wg-gesucht.de/img/placeholder/dummy_small.png);background-size: contain;"></a>
#  </div>
#  <div class="col-sm-8 card_body">
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <h3 class="truncate_title noprint" title="Suche Wochenendpendlerin!  Ehrenfeld: ruhiges, schönes, zentrales Zimmer">
#  <a href="/wg-zimmer-in-Koeln-Ehrenfeld.6654704.html">
#                              Suche Wochenendpendlerin!  Ehrenfeld: ruhiges, schönes, zentrales Zimmer
#                          </a>
#  </h3>
#  <div class="asset_favourite cursor-pointer" data-ad_id="6654704" data-ad_type="0" data-favourite_status="0">
#  <span aria-hidden="true" class="fav-button-6654704 mdi mdi-heart-outline icon-fav-empty" id="to-fav-6654704"></span>
#  </div>
#  </div>
#  <div class="col-xs-11">
#  <span>
#                          2er WG
#                           |
#
#                                                                                      Köln
#
#                              Ehrenfeld |
#
#                          Stamm Str. 74
#                      </span>
#  <span class="noprint" title="2er WG (1w,0m,0d)">
#  <img alt="weiblich" class="vis" height="17" src="/img/wgw.gif" style="margin-left:0px;" width="10"/><img alt="Mitbewohnerin gesucht" class="vis" height="17" src="/img/wgwg.gif" style="margin-left:0px;" width="10"/> </span>
#  </div>
#  </div>
#  <div class="row noprint middle">
#  <div class="col-xs-3">
#  <b>490 €</b>
#  </div>
#  <div class="col-xs-5 text-center">
#                                                                      15.04.2023
#
#                                              - 30.06.2023
#                                      </div>
#  <div class="col-xs-3 text-right">
#  <b>13 m²</b>
#  </div>
#  </div>
#  <div class="row noprint bottom">
#  <div class="col-xs-2">
#  <img class="avatar" src="/img/placeholder/no_profile_image_unisex.svg"/>
#  </div>
#  <div class="col-xs-9">
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <span>
#  </span>
#  <span>
#  </span>
#  </div>
#  </div>
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <span class="ml5">Bianca</span>
#  <span style="color: #218700;">Online: 1 Stunde</span>
#  </div>
#  </div>
#  </div>
#  <div class="col-xs-1 text-center p0">
#  <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden"></span>
#  </div>
#  </div>
#  </div>
#  <div class="printonly">
#  <a class="detailansicht" href="/wg-zimmer-in-Koeln-Ehrenfeld.6654704.html">
#  <b>Suche Wochenendpendlerin!  Ehrenfeld: ruhiges, schönes, zentrales Zimmer</b>
#  </a>
#  <br/>
#  <div>
#  <b>490 € |</b>
#  <b>13 m²</b>
#  </div>
#  <div>
#                  2er WG
#                   |
#
#                                                              Köln
#
#                      Ehrenfeld |
#
#                  Stamm Str. 74
#              </div>
#  <div style="margin-bottom:10px;">
#  <b>
#                      Verfügbar:
#                      15.04.2023
#                  </b>
#  </div>
#  <div style="margin-bottom:10px;">
#  <i>Diese Anzeige ist erreichbar unter:</i> https://www.wg-gesucht.de/6654704.html
#              </div>
#  <div style="border-top: 2px solid #ddd; margin-bottom:10px"></div>
#  </div>
#  </div>
#  </div>,
#  <div class="wgg_card offer_list_item" data-id="8086704" id="liste-details-ad-8086704">
#  <div class="row">
#  <div class="col-sm-4 card_image">
#  <a href="/wg-zimmer-in-Koeln-Ehrenfeld.8086704.html" style="background-image: url(https://www.wg-gesucht.de/img/placeholder/dummy_small.png);background-size: contain;"></a>
#  </div>
#  <div class="col-sm-8 card_body">
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <h3 class="truncate_title noprint" title="Suche Wochenendpendlerin!  Ehrenfeld: ruhiges, schönes, zentrales Zimmer">
#  <a href="/wg-zimmer-in-Koeln-Ehrenfeld.8086704.html">
#                              Suche Wochenendpendlerin!  Ehrenfeld: ruhiges, schönes, zentrales Zimmer
#                          </a>
#  </h3>
#  <div class="asset_favourite cursor-pointer" data-ad_id="8086704" data-ad_type="0" data-favourite_status="0">
#  <span aria-hidden="true" class="fav-button-8086704 mdi mdi-heart-outline icon-fav-empty" id="to-fav-8086704"></span>
#  </div>
#  </div>
#  <div class="col-xs-11">
#  <span>
#                          2er WG
#                           |
#
#                                                                                      Köln
#
#                              Ehrenfeld |
#
#                          Stamm Str. 74
#                      </span>
#  <span class="noprint" title="2er WG (1w,0m,0d)">
#  <img alt="weiblich" class="vis" height="17" src="/img/wgw.gif" style="margin-left:0px;" width="10"/><img alt="Mitbewohnerin gesucht" class="vis" height="17" src="/img/wgwg.gif" style="margin-left:0px;" width="10"/> </span>
#  </div>
#  </div>
#  <div class="row noprint middle">
#  <div class="col-xs-3">
#  <b>490 €</b>
#  </div>
#  <div class="col-xs-5 text-center">
#                                                                      15.04.2023
#
#                                              - 31.05.2023
#                                      </div>
#  <div class="col-xs-3 text-right">
#  <b>13 m²</b>
#  </div>
#  </div>
#  <div class="row noprint bottom">
#  <div class="col-xs-2">
#  <img class="avatar" src="/img/placeholder/no_profile_image_unisex.svg"/>
#  </div>
#  <div class="col-xs-9">
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <span>
#  </span>
#  <span>
#  </span>
#  </div>
#  </div>
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <span class="ml5">Bianca</span>
#  <span style="color: #218700;">Online: 1 Stunde</span>
#  </div>
#  </div>
#  </div>
# ...
#  <span>
#  </span>
#  </div>
#  </div>
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <span class="ml5">Marie</span>
#  <span style="color: #218700;">Online: 2 Stunden</span>
#  </div>
#  </div>
#  </div>
#  <div class="col-xs-1 text-center p0">
#  <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden"></span>
#  </div>
#  </div>
#  </div>
#  <div class="printonly">
#  <a class="detailansicht" href="/wg-zimmer-in-Koeln.9994515.html">
#  <b>Kleines, feines Reich am Stadtwald&lt;3</b>
#  </a>
#  <br/>
#  <div>
#  <b>436 € |</b>
#  <b>13 m²</b>
#  </div>
#  <div>
#                  3er WG
#                   |
#
#                                                              Köln |
#
#                  Stadtwaldgürtel
#              </div>
#  <div style="margin-bottom:10px;">
#  <b>
#                      Verfügbar:
#                      01.05.2023
#                  </b>
#  </div>
#  <div style="margin-bottom:10px;">
#  <i>Diese Anzeige ist erreichbar unter:</i> https://www.wg-gesucht.de/9994515.html
#              </div>
#  <div style="border-top: 2px solid #ddd; margin-bottom:10px"></div>
#  </div>
#  </div>
#  </div>,
#  <div class="wgg_card offer_list_item" data-id="3771180" id="liste-details-ad-3771180">
#  <div class="row">
#  <div class="col-sm-4 card_image">
#  <a href="/wg-zimmer-in-Koeln-Altstadt-Nord.3771180.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2020/41/d0e363509b262dce9a0a0f16f50ebb9e1619e27144be3ba171bae34c86d9f502_160266369964664772456.small.JPEG);"></a>
#  <div class="card_image_features">
#  <span class="card_image_feature_background card_image_feature_online_tour">
#  <span class="mdi mdi-cellphone mdi-16px mr5"></span>
#                              Online-Besichtigung
#                          </span>
#  </div>
#  </div>
#  <div class="col-sm-8 card_body">
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <h3 class="truncate_title noprint" title="Möbl.WG-Zimmer zur Zwi-Mi in Berufstätigen WG, direkt am Rhein, direkt in der Innenstadt zu vergeben">
#  <a href="/wg-zimmer-in-Koeln-Altstadt-Nord.3771180.html">
#                              Möbl.WG-Zimmer zur Zwi-Mi in Berufstätigen WG, direkt am Rhein, direkt in der Innenstadt zu vergeben
#                          </a>
#  </h3>
#  <div class="asset_favourite cursor-pointer" data-ad_id="3771180" data-ad_type="0" data-favourite_status="0">
#  <span aria-hidden="true" class="fav-button-3771180 mdi mdi-heart-outline icon-fav-empty" id="to-fav-3771180"></span>
#  </div>
#  </div>
#  <div class="col-xs-11">
#  <span>
#                          2er WG
#                           |
#
#                                                                                      Köln
#
#                              Altstadt-Nord |
#
#                          Alter Markt
#                      </span>
#  <span class="noprint" title="2er WG (1w,0m,0d)">
#  <img alt="weiblich" class="vis" height="17" src="/img/wgw.gif" style="margin-left:0px;" width="10"/><img alt="Mitbewohnerin gesucht" class="vis" height="17" src="/img/wgwg.gif" style="margin-left:0px;" width="10"/> </span>
#  </div>
#  </div>
#  <div class="row noprint middle">
#  <div class="col-xs-3">
#  <b>658 €</b>
#  </div>
#  <div class="col-xs-5 text-center">
#                                                                      01.05.2023
#
#                                              - 30.06.2023
#                                      </div>
#  <div class="col-xs-3 text-right">
#  <b>19 m²</b>
#  </div>
#  </div>
#  <div class="row noprint bottom">
#  <div class="col-xs-2">
#  <img class="avatar" src="/img/placeholder/no_profile_image_unisex.svg"/>
#  </div>
#  <div class="col-xs-9">
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <span>
#  </span>
#  <span>
#  </span>
#  </div>
#  </div>
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <span class="ml5">Veronica</span>
#  <span style="color: #218700;">Online: 2 Stunden</span>
#  </div>
#  </div>
#  </div>
#  <div class="col-xs-1 text-center p0">
#  <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden"></span>
#  </div>
#  </div>
#  </div>
#  <div class="printonly">
#  <a class="detailansicht" href="/wg-zimmer-in-Koeln-Altstadt-Nord.3771180.html">
#  <b>Möbl.WG-Zimmer zur Zwi-Mi in Berufstätigen WG, direkt am Rhein, direkt in der Innenstadt zu vergeben</b>
#  </a>
#  <br/>
#  <div>
#  <b>658 € |</b>
#  <b>19 m²</b>
#  </div>
#  <div>
#                  2er WG
#                   |
#
#                                                              Köln
#
#                      Altstadt-Nord |
#
#                  Alter Markt
#              </div>
#  <div style="margin-bottom:10px;">
#  <b>
#                      Verfügbar:
#                      01.05.2023
#                  </b>
#  </div>
#  <div style="margin-bottom:10px;">
#  <i>Diese Anzeige ist erreichbar unter:</i> https://www.wg-gesucht.de/3771180.html
#              </div>
#  <div style="border-top: 2px solid #ddd; margin-bottom:10px"></div>
#  </div>
#  </div>
#  </div>,
#  <div class="wgg_card offer_list_item" data-id="9980996" id="liste-details-ad-9980996">
#  <div class="row">
#  <div class="col-sm-4 card_image">
#  <a href="/wg-zimmer-in-Koeln-Ehrenfeld.9980996.html" style="background-image: url(https://www.wg-gesucht.de/img/placeholder/dummy_small.png);background-size: contain;"></a>
#  </div>
#  <div class="col-sm-8 card_body">
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <h3 class="truncate_title noprint" title="Die Miete enthält auch Strom, Gas und Internet.">
#  <a href="/wg-zimmer-in-Koeln-Ehrenfeld.9980996.html">
#                              Die Miete enthält auch Strom, Gas und Internet.
#                          </a>
#  </h3>
#  <div class="asset_favourite cursor-pointer" data-ad_id="9980996" data-ad_type="0" data-favourite_status="0">
#  <span aria-hidden="true" class="fav-button-9980996 mdi mdi-heart-outline icon-fav-empty" id="to-fav-9980996"></span>
#  </div>
#  </div>
#  <div class="col-xs-11">
#  <span>
#                          3er WG
#                           |
#
#                                                                                      Köln
#
#                              Ehrenfeld |
#
#                          Fröbelstraße 40
#                      </span>
#  <span class="noprint" title="3er WG (1w,1m,0d)">
#  <img alt="weiblich" class="vis" height="17" src="/img/wgw.gif" style="margin-left:0px;" width="10"/><img alt="Malmännliche" class="vis" height="17" src="/img/wgm.gif" style="margin-left:0px;" width="10"/><img alt="Mitbewohnerin oder Mitbwohner gesucht" class="vis" height="17" src="/img/wgeg.gif" style="margin-left:0px;" width="10"/> </span>
#  </div>
#  </div>
#  <div class="row noprint middle">
#  <div class="col-xs-3">
#  <b>440 €</b>
#  </div>
#  <div class="col-xs-5 text-center">
#                                                                      08.04.2023
#
#                                      </div>
#  <div class="col-xs-3 text-right">
#  <b>16 m²</b>
#  </div>
#  </div>
#  <div class="row noprint bottom">
#  <div class="col-xs-2">
#  <img class="avatar" src="/img/placeholder/no_profile_image_unisex.svg"/>
#  </div>
#  <div class="col-xs-9">
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <span>
#  </span>
#  <span>
#  </span>
#  </div>
#  </div>
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <span class="ml5">W. Louise</span>
#  <span style="color: #218700;">Online: 2 Stunden</span>
#  </div>
#  </div>
#  </div>
#  <div class="col-xs-1 text-center p0">
#  <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden"></span>
#  </div>
#  </div>
#  </div>
#  <div class="printonly">
#  <a class="detailansicht" href="/wg-zimmer-in-Koeln-Ehrenfeld.9980996.html">
#  <b>Die Miete enthält auch Strom, Gas und Internet.</b>
#  </a>
#  <br/>
#  <div>
#  <b>440 € |</b>
#  <b>16 m²</b>
#  </div>
#  <div>
#                  3er WG
#                   |
#
#                                                              Köln
#
#                      Ehrenfeld |
#
#                  Fröbelstraße 40
#              </div>
#  <div style="margin-bottom:10px;">
#  <b>
#                      Verfügbar:
#                      08.04.2023
#                  </b>
#  </div>
#  <div style="margin-bottom:10px;">
#  <i>Diese Anzeige ist erreichbar unter:</i> https://www.wg-gesucht.de/9980996.html
#              </div>
#  <div style="border-top: 2px solid #ddd; margin-bottom:10px"></div>
#  </div>
#  </div>
#  </div>,
#  <div class="wgg_card offer_list_item" data-id="9785226" id="liste-details-ad-9785226">
#  <div class="row">
#  <div class="col-sm-4 card_image">
#  <a href="/wg-zimmer-in-Koeln-Brueck-Lyn-.9785226.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2022/51/b1d13906fb5e8192cb8f559b5bca4203cc9d7002bfbe05c4c73da2d1cb4d5b09_167162195471194672595471155757.small.JPEG);"></a>
#  </div>
#  <div class="col-sm-8 card_body">
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <h3 class="truncate_title noprint" title="++ WG-Doppelplus ++ sucht Mitbewohner*in in Kölns grünem Osten">
#  <a href="/wg-zimmer-in-Koeln-Brueck-Lyn-.9785226.html">
#                              ++ WG-Doppelplus ++ sucht Mitbewohner*in in Kölns grünem Osten
#                          </a>
#  </h3>
#  <div class="asset_favourite cursor-pointer" data-ad_id="9785226" data-ad_type="0" data-favourite_status="0">
#  <span aria-hidden="true" class="fav-button-9785226 mdi mdi-heart-outline icon-fav-empty" id="to-fav-9785226"></span>
#  </div>
#  </div>
#  <div class="col-xs-11">
#  <span>
#                          4er WG
#                           |
#
#                                                                                      Köln
#
#                              Brück Lyn - |
#
#                          Fasanenweg
#                      </span>
#  <span class="noprint" title="4er WG (1w,2m,0d)">
#  <img alt="weiblich" class="vis" height="17" src="/img/wgw.gif" style="margin-left:0px;" width="10"/><img alt="Malmännliche" class="vis" height="17" src="/img/wgm.gif" style="margin-left:0px;" width="10"/><img alt="Malmännliche" class="vis" height="17" src="/img/wgm.gif" style="margin-left:0px;" width="10"/><img alt="Mitbewohnerin oder Mitbwohner gesucht" class="vis" height="17" src="/img/wgeg.gif" style="margin-left:0px;" width="10"/> </span>
#  </div>
#  </div>
#  <div class="row noprint middle">
#  <div class="col-xs-3">
#  <b>480 €</b>
#  </div>
#  <div class="col-xs-5 text-center">
#                                                                      22.04.2023
#
#                                      </div>
#  <div class="col-xs-3 text-right">
#  <b>15 m²</b>
#  </div>
#  </div>
#  <div class="row noprint bottom">
#  <div class="col-xs-2">
#  <img class="avatar" src="/img/placeholder/no_profile_image_unisex.svg"/>
#  </div>
#  <div class="col-xs-9">
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <span>
#  </span>
#  <span>
#  </span>
#  </div>
#  </div>
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <span class="ml5">Felix L.</span>
#  <span style="color: #218700;">Online: 2 Stunden</span>
#  </div>
#  </div>
#  </div>
#  <div class="col-xs-1 text-center p0">
#  <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden"></span>
#  </div>
#  </div>
#  </div>
#  <div class="printonly">
#  <a class="detailansicht" href="/wg-zimmer-in-Koeln-Brueck-Lyn-.9785226.html">
#  <b>++ WG-Doppelplus ++ sucht Mitbewohner*in in Kölns grünem Osten</b>
#  </a>
#  <br/>
#  <div>
#  <b>480 € |</b>
#  <b>15 m²</b>
#  </div>
#  <div>
#                  4er WG
#                   |
#
#                                                              Köln
#
#                      Brück Lyn - |
#
#                  Fasanenweg
#              </div>
#  <div style="margin-bottom:10px;">
#  <b>
#                      Verfügbar:
#                      22.04.2023
#                  </b>
#  </div>
#  <div style="margin-bottom:10px;">
#  <i>Diese Anzeige ist erreichbar unter:</i> https://www.wg-gesucht.de/9785226.html
#              </div>
#  <div style="border-top: 2px solid #ddd; margin-bottom:10px"></div>
#  </div>
#  </div>
#  </div>,
#  <div class="wgg_card offer_list_item" data-id="9996738" id="liste-details-ad-9996738">
#  <div class="row">
#  <div class="col-sm-4 card_image">
#  <a href="/wg-zimmer-in-Koeln-Neuehrenfeld.9996738.html" style="background-image: url(https://www.wg-gesucht.de/img/placeholder/dummy_small.png);background-size: contain;"></a>
#  </div>
#  <div class="col-sm-8 card_body">
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <h3 class="truncate_title noprint" title="Alle Zimmer sind ungefähr gleich groß.">
#  <a href="/wg-zimmer-in-Koeln-Neuehrenfeld.9996738.html">
#                              Alle Zimmer sind ungefähr gleich groß.
#                          </a>
#  </h3>
#  <div class="asset_favourite cursor-pointer" data-ad_id="9996738" data-ad_type="0" data-favourite_status="0">
#  <span aria-hidden="true" class="fav-button-9996738 mdi mdi-heart-outline icon-fav-empty" id="to-fav-9996738"></span>
#  </div>
#  </div>
#  <div class="col-xs-11">
#  <span>
#                          3er WG
#                           |
#
#                                                                                      Köln
#
#                              Neuehrenfeld |
#
#                          Vogelsanger Str. 185
#                      </span>
#  <span class="noprint" title="3er WG (1w,1m,0d)">
#  <img alt="weiblich" class="vis" height="17" src="/img/wgw.gif" style="margin-left:0px;" width="10"/><img alt="Malmännliche" class="vis" height="17" src="/img/wgm.gif" style="margin-left:0px;" width="10"/><img alt="Mitbewohnerin oder Mitbwohner gesucht" class="vis" height="17" src="/img/wgeg.gif" style="margin-left:0px;" width="10"/> </span>
#  </div>
#  </div>
#  <div class="row noprint middle">
#  <div class="col-xs-3">
#  <b>460 €</b>
#  </div>
#  <div class="col-xs-5 text-center">
#                                                                      01.05.2023
#
#                                      </div>
#  <div class="col-xs-3 text-right">
#  <b>18 m²</b>
#  </div>
#  </div>
#  <div class="row noprint bottom">
#  <div class="col-xs-2">
#  <img class="avatar" src="/img/placeholder/no_profile_image_unisex.svg"/>
#  </div>
#  <div class="col-xs-9">
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <span>
#  </span>
#  <span>
#  </span>
#  </div>
#  </div>
#  <div class="row noprint">
#  <div class="col-sm-12 flex_space_between">
#  <span class="ml5">K. Fave</span>
#  <span style="color: #218700;">Online: 2 Stunden</span>
#  </div>
#  </div>
#  </div>
#  <div class="col-xs-1 text-center p0">
#  <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden"></span>
#  </div>
#  </div>
#  </div>
#  <div class="printonly">
#  <a class="detailansicht" href="/wg-zimmer-in-Koeln-Neuehrenfeld.9996738.html">
#  <b>Alle Zimmer sind ungefähr gleich groß.</b>
#  </a>
#  <br/>
#  <div>
#  <b>460 € |</b>
#  <b>18 m²</b>
#  </div>
#  <div>
#                  3er WG
#                   |
#
#                                                              Köln
#
#                      Neuehrenfeld |
#
#                  Vogelsanger Str. 185
#              </div>
#  <div style="margin-bottom:10px;">
#  <b>
#                      Verfügbar:
#                      01.05.2023
#                  </b>
#  </div>
#  <div style="margin-bottom:10px;">
#  <i>Diese Anzeige ist erreichbar unter:</i> https://www.wg-gesucht.de/9996738.html
#              </div>
#  <div style="border-top: 2px solid #ddd; margin-bottom:10px"></div>
#  </div>
#  </div>
#  </div>]

# %%
# Out:
# 3er WG, Köln, Gremberghoven, Feldbergstr. 14
# 4er WG, Köln, Raderthal, Hitzelerstr. 50
# 3er WG, Köln, Sülz, Nikolausstr. 69
# 2er WG, Köln, Neustadt-Süd, Ohmstr. 38
# 2er WG, Köln, Bickendorf, Feltenstr
# 2er WG, Köln, Altstadt-Nord, Krefelderstraße 20
# 2er WG, Köln, Sülz, Nikolausstr.131
# 3er WG, Köln, Kalscheurer, Weg
# 3er WG, Köln, Sülz, Rennebergstr.
# 7er WG, Köln, Bornheim, - Sechtem |                                                Bahnhofstr. 3
# 2er WG, Köln, Ehrenfeld, Stamm Str. 74
# 2er WG, Köln, Ehrenfeld, Stamm Str. 74
# 3er WG, Köln, Weiß, Am Rheinberg 9
# 6er WG, Köln, Altstadt-Nord, Aquinostraße
# 3er WG, Köln, Stadtwaldgürte, l
# 2er WG, Köln, Altstadt-Nord, Alter Markt
# 3er WG, Köln, Ehrenfeld, Fröbelstraße 40
# 4er WG, Köln, Brück, Lyn - |                                                Fasanenweg
# 3er WG, Köln, Neuehrenfeld, Vogelsanger Str. 185
# 4er WG, Köln, Christinast, r

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# prompt the user to enter the desired city, maximum rent price, and minimum room size
city = input("Enter the desired city: ")
max_price = int(input("Enter the maximum rent price: "))
min_size = int(input("Enter the minimum room size: "))

# construct the URL for the search results page for the desired city and with the specified filters
url = f"https://www.wg-gesucht.de/wg-zimmer-in-{city}.73.0.1.0.html?maxrent={max_price}&minsize={min_size}"

# send a GET request to the URL and get the HTML content of the page
response = requests.get(url)

html_content = response.content

# parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# find all listings on the page
listings = soup.find_all(class_='wgg_card offer_list_item')

# define a regular expression pattern to match the relevant information in the string
pattern = r"(\der WG)[\s|]*(\S+)[\s|]*(\S+)[\s|]*(\S+.*)"

# create a list to store the details of each listing
details_list = []

# loop through each listing and extract the details
for listing in listings:
    title = listing.find(class_='truncate_title noprint').text.strip()
    price = listing.find(class_='col-xs-3').text.strip()
    size = listing.find(class_='col-xs-3 text-right').text.strip()
    merged_infos = listing.find(class_='col-xs-11').text.replace('\n', '')

    # use regex to extract the relevant information from the merged_infos string
    match = re.search(pattern, merged_infos, re.MULTILINE)
    if match is not None:
        wg_type = match.group(1)
        city = match.group(2).strip()
        district = match.group(3).strip()
        street = match.group(4).strip()
    else:
        print("No match found")

    # add the details to the list if the price is below the maximum and the size is above the minimum
    if int(price.split()[0]) <= max_price and int(size.split()[0]) >= min_size:
        details_list.append([title, price, size, wg_type, city, district, street])

# create a pandas dataframe from the details list
df = pd.DataFrame(details_list, columns=["Title", "Price", "Size", "Type", "City", "District", "Street"])

# save the dataframe to a CSV file in the current directory
df.to_csv("wg_results.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 8
#       6 # prompt the user to enter the desired city, maximum rent price, and minimum room size
#       7 city = input("Enter the desired city: ")
# ----> 8 max_price = int(input("Enter the maximum rent price: "))
#       9 min_size = int(input("Enter the minimum room size: "))
#      11 # construct the URL for the search results page for the desired city and with the specified filters
#
# ValueError: invalid literal for int() with base 10: ''

# %%
wg_type
# Out:
# '4er WG'

# %%
merged_infos.replace('\n', '')
# Out:
# '3er WG                           |                                                                                    Köln                                                        Sülz |                                                Rennebergstr.'

# %%
merged_infos
# Out:
# '                        2er WG                           |                                                                                    Köln                                                        Agnesviertel |                                                Ewaldistraße                     '
