# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import os
import logging
from unidecode import unidecode

city = "Köln"
max_rent = 500
min_size = 15

# specify the URL of the search results page for Cologne WG-Zimmer on wg-gesucht.de
url = f"https://www.wg-gesucht.de/wg-zimmer-in-Koeln.73.0.1.0.html?offer_filter=1&city_id=73&sort_order=0&noDeact=1&categories%5B%5D=0&rent_types%5B%5D=0&sMin={min_size}&rMax={max_rent}"


# specify the URL of the search results page for Cologne WG-Zimmer on wg-gesucht.de
#url = "https://www.wg-gesucht.de/wg-zimmer-in-Koeln.73.0.1.0.html"
# send a GET request to the URL and get the HTML content of the page
response = requests.get(url)

html_content = response.content

# parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# find all listings on the page
listings = soup.find_all(class_='wgg_card offer_list_item')

# define a regular expression pattern to match the relevant information in the string
pattern = r"(\d)er WG[\s|]*(\S+)[\s|]*(\S+)[\s|]*(\S+.*)"

# create an empty list to store the data
data = []

# set up logging
logging.basicConfig(filename='./logs/merged_info.log', level=logging.INFO, format='%(asctime)s:%(message)s')

# loop through each listing and extract the information
for listing in listings:
    title = listing.find(class_='truncate_title noprint').text.strip()
    price = listing.find(class_='col-xs-3').text.strip()
    size = listing.find(class_='col-xs-3 text-right').text.strip()
    
    # parse single informations with regex
    merged_infos = listing.find(class_='col-xs-11').text.replace('\n', '')
    
    # log the value of merged_infos
    logging.info(merged_infos)

    match = re.search(pattern, merged_infos, re.MULTILINE)
    if match is not None:
        # extract the relevant information from the match object
        wg_type = match.group(1)
        city = match.group(2).strip()
        district = match.group(3).strip()
        street = match.group(4).strip()
        
        # append the extracted data to the list
        data.append([title, price, size, wg_type, city, district, street])
    
    else: 
        print("No match found")

# create a pandas DataFrame from the extracted data
df = pd.DataFrame(data, columns=['Title', 'Price', 'Size', 'WG Type', 'City', 'District', 'Street'])

# save the DataFrame to a CSV file in the current working directory
file_path = os.path.join(os.getcwd(), './data/wg_listings.csv')
df.to_csv(file_path, index=False)

# print a message to confirm that the file has been saved
print(f"DataFrame saved to {file_path}")

df
# Out:
# DataFrame saved to c:\Coding\wggesucht_webscraper\./data/wg_listings.csv
#                                                 Title  Price   Size WG Type
# 0                             Süßes, helles WG-Zimmer  480 €  19 m²       3  \
# 1                             Große Haus-WG Köln/Bonn  499 €  18 m²       7
# 2   Zwischenmiete in gemütlicher 5er-WG in Köln Ka...  455 €  16 m²       5
# 3                                 Kalker Schmuckstück  464 €  21 m²       3
# 4     Die Miete enthält auch Strom, Gas und Internet.  440 €  16 m²       3
# 5   FuWo-Friends 🌈 open minded People Köln 🤗🌿 FuWo...  100 €  30 m²       0
# 6              Alle Zimmer sind ungefähr gleich groß.  460 €  18 m²       3
# 7   City UniKlinik,Uni , 2RaumSingleApartment, Möb...  490 €  30 m²       2
# 8   Studentenzimmer in Verbindungsvilla (Studenten...  290 €  20 m²       9
# 9                    16qm Zimmer in 2er WG - Südstadt  475 €  16 m²       2
# 10        Mehrere Zimmer in Studenten-WG (in Uninähe)  290 €  15 m²       8
# 11  Room In WG Meschenich Köln Available Till 31.0...  300 €  16 m²       3
# 12  Room In WG Meschenich Köln Available Till 31.0...  350 €  20 m²       2
# 13                 3 Monate Sommer zentral mit Garten  450 €  15 m²       2
# 14  ein Zimmer in einer Wohnung schön eingerichtet...  410 €  20 m²       2
# 15                                        Köln-Nippes  475 €  16 m²       2
# 16                              Mitbewohnerin gesucht  250 €  15 m²       2
# 17                         WG Zimmer in Neu Ehrenfeld  480 €  20 m²       4
# 18  Zimmer (Nr. 31) 26 qm in katholischer Studente...  348 €  26 m²       0
# 19  Ruhiges Zimmer im Haus mit Garten und direkt a...  400 €  15 m²       3
#
#     City                 District
# 0   Köln             Altstadt-Süd  \
# 1   Köln                 Bornheim
# 2   Köln        Humboldt/Gremberg
# 3   Köln        Humboldt-Gremberg
# 4   Köln                Ehrenfeld
# 5   Köln                 Telegram
# 6   Köln             Neuehrenfeld
# 7   Köln                     Sülz
# 8   Köln               Lindenthal
# 9   Köln             Altstadt-Süd
# 10  Köln  Joseph-Stelzmann-Straße
# 11  Köln               Meschenich
# 12  Köln               Meschenich
# 13  Köln                   Nippes
# 14  Köln                     Köln
# 15  Köln                   Nippes
# 16  Köln                Ehrenfeld
# 17  Köln             Neuehrenfeld
# 18  Köln              Klettenberg
# 19  Köln                wahnheide
#
#                                                Street
# 0                                      Rolandstraße 5
# 1   - Sechtem |                                   ...
# 2                                         Esserstraße
# 3                                    Feldbergstraße x
# 4                                     Fröbelstraße 40
# 5                                              Gruppe
# 6                                Vogelsanger Str. 185
# 7                                     Nikolausstr.131
# 8                                      Heinestraße 30
# 9                                    Zwirnerstraße 41
# 10                                                  7
# 11                                      An der Fuhr 1
# 12                                      An der Fuhr 1
# 13                                        Krüthstraße
# 14                                        Siebachstr.
# 15                                     Nettelbeckstr.
# 16                                          Ehrenfeld
# 17                                      Grolmanstr.43
# 18                                   Wolkenburgstr. 3
# 19                                     Magazinstrasse
