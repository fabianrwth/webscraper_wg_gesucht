# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import os
import logging
from unidecode import unidecode

city = "Köln"
max_rent = 500
min_size = 15

# specify the URL of the search results page for Cologne WG-Zimmer on wg-gesucht.de
url = f"https://www.wg-gesucht.de/wg-zimmer-in-Koeln.73.0.1.0.html?offer_filter=1&city_id=73&sort_order=0&noDeact=1&categories%5B%5D=0&rent_types%5B%5D=0&sMin={min_size}&rMax={max_rent}"


# specify the URL of the search results page for Cologne WG-Zimmer on wg-gesucht.de
#url = "https://www.wg-gesucht.de/wg-zimmer-in-Koeln.73.0.1.0.html"
# send a GET request to the URL and get the HTML content of the page
response = requests.get(url)

html_content = response.content

# parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# find all listings on the page
listings = soup.find_all(class_='wgg_card offer_list_item')

# define a regular expression pattern to match the relevant information in the string
pattern = r"(\d)er WG[\s|]*(\S+)[\s|]*(\S+)[\s|]*(\S+.*)"

# create an empty list to store the data
data = []

# set up logging
logging.basicConfig(filename='merged_info.log', level=logging.INFO, format='%(asctime)s:%(message)s')

# loop through each listing and extract the information
for listing in listings:
    title = listing.find(class_='truncate_title noprint').text.strip()
    price = listing.find(class_='col-xs-3').text.strip()
    size = listing.find(class_='col-xs-3 text-right').text.strip()
    
    # parse single informations with regex
    merged_infos = listing.find(class_='col-xs-11').text.replace('\n', '')
    
    # log the value of merged_infos
    logging.info(merged_infos)

    match = re.search(pattern, merged_infos, re.MULTILINE)
    if match is not None:
        # extract the relevant information from the match object
        wg_type = match.group(1)
        city = match.group(2).strip()
        district = match.group(3).strip()
        street = match.group(4).strip()
        
        # append the extracted data to the list
        data.append([title, price, size, wg_type, city, district, street])
    
    else: 
        print("No match found")

# create a pandas DataFrame from the extracted data
df = pd.DataFrame(data, columns=['Title', 'Price', 'Size', 'WG Type', 'City', 'District', 'Street'])

# save the DataFrame to a CSV file in the current working directory
file_path = os.path.join(os.getcwd(), 'wg_listings.csv')
df.to_csv(file_path, index=False)

# print a message to confirm that the file has been saved
print(f"DataFrame saved to {file_path}")

df
# Out:
# DataFrame saved to c:\Coding\wggesucht_webscraper\wg_listings.csv
#                                                 Title  Price   Size WG Type
# 0                          WG Zimmer in Neu Ehrenfeld  480 €  20 m²       4  \
# 1   City UniKlinik,Uni , 2RaumSingleApartment, Möb...  490 €  30 m²       2
# 2                    16qm Zimmer in 2er WG - Südstadt  475 €  16 m²       2
# 3   Zimmer (Nr. 31) 26 qm in katholischer Studente...  348 €  26 m²       0
# 4   Ruhiges Zimmer im Haus mit Garten und direkt a...  400 €  15 m²       3
# 5   SHORT term Rent (June-July) Zwischenmiete clos...  450 €  15 m²       3
# 6                WG-Zimmer am Rhein zur Zwischenmiete  490 €  16 m²       2
# 7     WG Zimmer in Köln Zollstock ab sofort beziehbar  500 €  16 m²       3
# 8   FuWo-Friends 🌈 open minded People Köln 🤗🌿 FuWo...  100 €  30 m²       0
# 9              Alle Zimmer sind ungefähr gleich groß.  460 €  18 m²       3
# 10    Die Miete enthält auch Strom, Gas und Internet.  440 €  16 m²       3
# 11                              Mitbewohnerin gesucht  250 €  15 m²       2
# 12                            Süßes, helles WG-Zimmer  480 €  19 m²       3
# 13                     WG-Zimmer für Studenten (18m²)  346 €  18 m²       3
# 14  WG-Zimmer (18m² / 2.Stock) bei der Burschensch...  346 €  18 m²       3
# 15                            WG-Zimmer in Lindenthal  360 €  15 m²       6
# 16     Günstige Wohlfühloase nahe Zentrums mit Balkon  300 €  18 m²       2
# 17                            Große Haus-WG Köln/Bonn  499 €  18 m²       7
# 18  ++ WG-Doppelplus ++ sucht Mitbewohner*in in Kö...  480 €  15 m²       4
# 19                 schönes, helles WG-Zimmer am Rhein  450 €  15 m²       2
#
#     City      District                                             Street
# 0   Köln  Neuehrenfeld                                      Grolmanstr.43
# 1   Köln          Sülz                                    Nikolausstr.131
# 2   Köln  Altstadt-Süd                                   Zwirnerstraße 41
# 3   Köln   Klettenberg                                   Wolkenburgstr. 3
# 4   Köln     wahnheide                                     Magazinstrasse
# 5   Köln          Köln                                           Blaubach
# 6   Köln         Deutz                                      Bebelplatz 18
# 7   Köln     Zollstock                              Kierberger Strasse 15
# 8   Köln      Telegram                                             Gruppe
# 9   Köln  Neuehrenfeld                               Vogelsanger Str. 185
# 10  Köln     Ehrenfeld                                    Fröbelstraße 40
# 11  Köln     Ehrenfeld                                          Ehrenfeld
# 12  Köln  Altstadt-Süd                                     Rolandstraße 5
# 13  Köln     Zülpicher                                          Straße 35
# 14  Köln     Zülpicher                                          Straße 35
# 15  Köln    Lindenthal                                Bachemerstraße 107a
# 16  Köln    Bickendorf                                          Feltenstr
# 17  Köln      Bornheim  - Sechtem |                                   ...
# 18  Köln         Brück  Lyn - |                                       ...
# 19  Köln         Riehl                               Rotterdamer Straße 6
